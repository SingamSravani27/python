# %%
###
name="sravani"
age=20
### My name sravani and i am a 20 years old
print("My name " + name + " and iam a " +str(age)+ " years old")     ###TypeError: can only concatenate str (not "int") to s
# Out:
# My name sravani and iam a 20 years old

# %%
###Output formating 
##1.Old Style Formatting (using comma)
name="sravani"
age=20
marks=[83,35,32,89,65]
### My name sravani and i am a 20 years old
print("My name" , name , "and i am a " ,age, "years old", 20)
# Out:
# My name sravani and i am a  20 years old 20

# %%
#  2.Access Specifiers
#integer-%d
#float-%f
#string-%s

name="sravani"
age=20
marks=[83,35,32,89,65]
### My name sravani and i am a 20 years old
print("My name %s and i am a age %d years old"%(name,age))

##print("My name %s and i am a age %d years old"%(age,name)) ###TypeError: %d format: a real number is required, not str
# Out:
# My name sravani and i am a age 20 years old

# %%
###Output formating 
##   3. Dot FORMAT
name="sravani"
age=20
marks=[83,35,32,89,65]
### My name sravani and i am a 20 years old
print("My name {} and i am a {} years old".format(name,age))
print("My name {} and i am a {} years old".format(age,name))
# Out:
# My name sravani and i am a 20 years old
# My name 20 and i am a sravani years old

# %%
### 4.f-Format
name="sravani"
age=20
marks=[83,35,32,89,65]
### My name sravani and i am a 20 years old
percentage=98.29843567
print(f"My name {name}. and i am a {age} years old and my percentage is {percentage}")
print(f"My name {name}. and i am a {age} years old and my percentage is {percentage:.2f}")
# Out:
# My name sravani. and i am a 20 years old and my percentage is 98.29843567
# My name sravani. and i am a 20 years old and my percentage is 98.30
