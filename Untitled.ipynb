# %%
#Run time errors
arr=[10,20,30]
arr.remove(100)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Run time errors
#       2 arr=[10,20,30]
# ----> 3 arr.remove(100)
#       4 print(arr)
#
# ValueError: list.remove(x): x not in list

# %%
#Run time errors
arr=[10,20,30]
arr.index(100)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Run time errors
#       2 arr=[10,20,30]
# ----> 3 arr.index(100)
#       4 print(arr)
#
# ValueError: list.index(x): x not in list

# %%
arr=[]
arr.pop()
print(arr)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 arr=[]
# ----> 2 arr.pop()
#       3 print(arr)
#
# IndexError: pop from empty list

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
print(int('abc'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(int('abc'))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
## Exception Handline Blocks
## Without exception
try:
    a=int(input())
    b=int(input())
    c=a+b
    print(c)
except:
    print("Something wrong in Try Block")
else:
    print("There is no Exception in try block")
finally:
    print("Program Done")
# Out:
#  10
#  20
# 30
# There is no Exception in try block
# Program Done

# %%
## Exception Handline Blocks
## With an exception
try:
    a=int(input())
    b=int(input())
    c=a+b
    print(c)
except:
    print("Something wrong in Try Block")
else:
    print("There is no Exception in try block")
finally:
    print("Program Done")
# Out:
#  10
#  Sravani
# Something wrong in Try Block
# Program Done

# %%
a=10
b=0
c=a/b
print (c)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 a=10
#       2 b=0
# ----> 3 c=a/b
#       4 print (c)
#
# ZeroDivisionError: division by zero

# %%
## Exception Handline Blocks
## Exception with Exception class
try:
    a=10
    b=0
    c=a/b
    print(c)
except Exception as e:
    print(f"Something wrong in Try Block:{e}")
# Out:
# Something wrong in Try Block:division by zero

# %%
## Exception Handline Blocks
## define multiple exception with difference except block
try:
    a=10
    b=0
    c=a/b
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not Possible:{e}")
except IndexError as e:
    print(f" We can't access element  this position{e}")
except Exception as e:
    print(f"Something wrong in Try Block:{e}")
# Out:
#  Zero division not Possible:division by zero

# %%
## Exception Handline Blocks
## define multiple exception with difference except block
try:
    arr=[1,2,3,4]
    c=arr[10]
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not Possible:{e}")
except IndexError as e:
    print(f" We can't access element this position{e}")
except Exception as e:
    print(f"Something wrong in Try Block:{e}")
# Out:
#  We can't access element this positionlist index out of range

# %%
## Exception Handline Blocks
## define multiple exception with difference except block
try:
    arr=10
    c=len(a)
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not Possible:{e}")
except IndexError as e:
    print(f" We can't access element this position{e}")
except Exception as e:
    print(f"Something wrong in Try Block:{e}")
# Out:
# Something wrong in Try Block:object of type 'int' has no len()

# %%
## Exception Handline Blocks
## define multiple exception with difference except block
try:
    arr=10
    c=len(a)
    print(c)
except ZeroDivisionError as e:
    print(f" Zero division not Possible:{e}")
except IndexError as e:
    print(f" We can't access element this position{e}")
#except Exception as e:
#    print(f"Something wrong in Try Block:{e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       5     c=len(a)
#       6     print(c)
#       7 except ZeroDivisionError as e:
#       8     print(f" Zero division not Possible:{e}")
# ----> 9 except IndexError as e:
#      10     print(f" We can't access element this position{e}")
#      11 #except Exception as e:
#      12 #    print(f"Something wrong in Try Block:{e}")
#
# TypeError: object of type 'int' has no len()
