# %%
from datetime import datetime, timedelta
curr_timestamp=datetime.now() ##to get cuurent timestamp
print(curr_timestamp)
today=curr_timestamp.date() ## It extracts date from timestamp
curr_time=curr_timestamp.time() ## it extract time
print(today)
print(curr_time)
print(today.year)
print(today.month)
print(today.day)
print(curr_time.hour,curr_time.minute, curr_time.second)
print(today.strftime("%d-%m-%Y"))
print(curr_time.strftime("%I:%M %p"))
print(curr_time.strftime("%H:%M %S"))
# Out:
# 2026-08-12 15:05:01.230281
# 2026-08-12
# 15:05:01.230281
# 2026
# 8
# 12
# 15 5 1
# 12-08-2026
# 01-05-00
# 03:05 PM
# 15:05 01

# %%
import time 
print("Hi")
time.sleep(5)
print("Hello")
# Out:
# Hi
# Hello

# %%
import time

sec = 0
minute = 0
hour = 0

while True:
    print(f"{hour:00d}:{minute:02d}:{sec:00d}")

    time.sleep(1)

    sec += 1

    if sec == 60:
        sec = 0
        minute += 1

    if minute == 60:
        minute = 0
        hour += 1
# Out:
# 0:00:0
# 0:00:1
# 0:00:2
# 0:00:3
# 0:00:4
# 0:00:5
# 0:00:6
# 0:00:7
# 0:00:8
# 0:00:9
# 0:00:10
# 0:00:11
# 0:00:12
# 0:00:13
# 0:00:14
# 0:00:15
# 0:00:16
# 0:00:17
# 0:00:18
# 0:00:19
# 0:00:20
# 0:00:21
# 0:00:22
# 0:00:23
# 0:00:24
# 0:00:25
# 0:00:26
# 0:00:27
# 0:00:28
# 0:00:29
# 0:00:30
# 0:00:31
# 0:00:32
# 0:00:33
# 0:00:34
# 0:00:35
# 0:00:36
# 0:00:37
# 0:00:38
# 0:00:39
# 0:00:40
# 0:00:41
# 0:00:42
# 0:00:43
# 0:00:44
# 0:00:45
# 0:00:46
# 0:00:47
# 0:00:48
# 0:00:49
# 0:00:50
# 0:00:51
# 0:00:52
# 0:00:53
# 0:00:54
# 0:00:55
# 0:00:56
# 0:00:57
# 0:00:58
# 0:00:59
# 0:01:0
# 0:01:1
# 0:01:2
# 0:01:3
# 0:01:4
# 0:01:5
# 0:01:6
# 0:01:7
# 0:01:8
# 0:01:9
# 0:01:10
# 0:01:11
# 0:01:12
# 0:01:13
# 0:01:14
# 0:01:15
# 0:01:16
# 0:01:17
# 0:01:18
# 0:01:19
# 0:01:20
# 0:01:21
# 0:01:22
# 0:01:23
# 0:01:24
# 0:01:25
# 0:01:26
# 0:01:27
# 0:01:28
# 0:01:29
# 0:01:30
# 0:01:31
# 0:01:32
# 0:01:33
# 0:01:34
# 0:01:35
# 0:01:36
# 0:01:37
# 0:01:38
# 0:01:39
# 0:01:40
# 0:01:41
# 0:01:42
# 0:01:43
# 0:01:44
# 0:01:45
# 0:01:46
# 0:01:47
# 0:01:48
# 0:01:49
# 0:01:50
# 0:01:51
# 0:01:52
# 0:01:53
# 0:01:54
# 0:01:55
# 0:01:56
# 0:01:57
# 0:01:58
# 0:01:59
# 0:02:0
# 0:02:1
# 0:02:2
# 0:02:3
# 0:02:4
# 0:02:5
# 0:02:6
# 0:02:7
# 0:02:8
# 0:02:9
# 0:02:10
# 0:02:11
# 0:02:12
# 0:02:13
# 0:02:14
# 0:02:15
# 0:02:16
# 0:02:17
# 0:02:18
# 0:02:19
# 0:02:20
# 0:02:21
# 0:02:22
# 0:02:23
# 0:02:24

# %%
import time
from IPython.display import clear_output
sec_counter= min_counter=hour_counter=0
while True:
    print(f"{hour_counter}:{min_counter}:{sec_counter}")
    time.sleep(1)
    sec_counter+=1
    if sec_counter==60:
        min_counter +=1
        sec_counter=0
        if min_counter==60:
            hour_counter+=1
            min_counter=0
            if hour_counter==24:
                hour_counter=0
    clear_output(wait=True)
# Out:
# 0:28:7

# %%
import time
from IPython.display import clear_output
minutes=int(input("Enter stop watch minutes:"))
sec_counter= min_counter=hour_counter=0
while min_counter!=minutes:
    print(f"{hour_counter}:{min_counter}:{sec_counter}")
    time.sleep(1)
    sec_counter+=1
    if sec_counter==60:
        min_counter +=1
        sec_counter=0
        if min_counter==60:
            hour_counter+=1
            min_counter=0
            if hour_counter==24:
                hour_counter=0
    clear_output(wait=True)
# Out:
# 0:0:59

# %%
import time
from IPython.display import clear_output
minutes=int(input("Enter stop watch minutes:"))
sec_counter= min_counter=hour_counter=0
while min_counter!=minutes:
    
    time.sleep(1)
    sec_counter+=1
    if sec_counter==60:
        min_counter +=1
        sec_counter=0
        if min_counter==60:
            hour_counter+=1
            min_counter=0
            if hour_counter==24:
                hour_counter=0
    print(f"{hour_counter}:{min_counter}:{sec_counter}")
    clear_output(wait=True)
# Out:
# 0:1:0
