# %%
n=input()
print(type(n))
print(n)
# Out:
#  sravani
# <class 'str'>
# sravani

# %%
## reading integer from user
### Integer to float,string, bool
n=int(input())
print(type(n),n)
print(float(n))
print(str(n))  ###o/p formate is string type
print(bool(n))
# Out:
#  25
# <class 'int'> 25
# 25.0
# 25
# True

# %%
## reading float from user
### float to int,string, bool
val=float(input())
print(type(val),val)
print(str(val))
print(bool(val))
print(int(val))
# Out:
#  2.25
# <class 'float'> 2.25
# 2.25
# True
# 2

# %%
## reading bool from user
### bool to int,string, bool
val=bool(input())
print(type(val),val)
print(str(val))
print(int(val))
# Out:
#  2.5
# <class 'bool'> True
# True
# 1

# %%
##reading complex value
real=int(input())
img=int(input())
c=complex(real,img)
print(type(c),c)
# Out:
#  10
#  5
# <class 'complex'> (10+5j)

# %%
## string(character)
a=str(input())
print(type(a),a)
##print(type(a))
l=list(a)
print(l[-4:5])    ### It returns list of characters
print(tuple(a     ### It returns list of characters
print(set(a))     ### It returns list of characters
# Out:
#  hello
# <class 'str'> hello
# ['e', 'l', 'l', 'o']
# ('h', 'e', 'l', 'l', 'o')
# {'l', 'h', 'o', 'e'}

# %%
### string(integer) in this we can perform list,tuple,set 
a=str(input())
print(type(a),a)
print(int(a))
print(float(a))
print(bool(a))
######################################################
print(list(a))      ### It returns list of characters
print(tuple(a))     ### It returns list of characters
print(set(a))       ### It returns list of characters
# Out:
#  120
# <class 'str'> 120
# 120
# 120.0
# True
# ['1', '2', '0']
# ('1', '2', '0')
# {'0', '1', '2'}

# %%
### reading list of integers
s=input().split()
print(s)
# Out:
#  1 2 3
# ['1', '2', '3']

# %%
s=map(int,input().split())
print(s)
# Out:
#  1 2 3
# ...

# %%
## List to tuple, set, string
l=list(map(int,input().split()))
print(l)
print(tuple(l))
print(set(l))
s=str(l)
print(s[0])
print(s)
# Out:
#  1 2 3
# [1, 2, 3]
# (1, 2, 3)
# {1, 2, 3}
# [
# [1, 2, 3]

# %%
## Read list of strings
l=list(map(str,input().split()))
print(l)
# Out:
#  hello hi welcome y m
# ['hello', 'hi', 'welcome', 'y', 'm']

# %%
## reading tuple of integers
t=tuple(map(int,input().split()))
print(list(t))
print(set(t))
print(str(t))
# Out:
#  1 2 3 4 -54 -45
# [1, 2, 3, 4, -54, -45]
# {1, 2, 3, 4, -54, -45}
# (1, 2, 3, 4, -54, -45)

# %%
### reading set of integers
s=set(map(int,input().split()))
print(list(s))
print(set(s))
print(str(s))
# Out:
#  2 3 45 67 23 -34
# [2, 67, 3, 45, 23, -34]
# {2, 67, 3, 23, 45, -34}
# {2, 67, 3, 45, 23, -34}

# %%
###Eval() : It evalutes the string type expression
print("3+5")
print(3+5)
print(eval("3+5"))
# Out:
# 3+5
# 8
# 8

# %%
n=eval(input())
print(type(n),n)
# Out:
#  "hello"
# <class 'str'> hello

# %%
n=eval(input())
print(type(n),n)
# Out:
#  [1,2,3]
# <class 'list'> [1, 2, 3]

# %%
n=eval(input())
print(type(n),n)
# Out:
#  (1,2,3)
# <class 'tuple'> (1, 2, 3)

# %%
n=eval(input())
print(type(n),n)
# Out:
#  {"name":"sravani", "age": 22}
# <class 'dict'> {'name': 'sravani', 'age': 22}
